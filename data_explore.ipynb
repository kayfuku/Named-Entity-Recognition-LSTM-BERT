# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# From Wikipedia 
# https://raw.githubusercontent.com/Hironsan/IOB2Corpus/master/ja.wikipedia.conll
# wiki = pd.read_csv('data/ja.wikipedia.conll', header=None, sep='\t', engine='python')
wiki = pd.read_csv('data/ja.wikipedia.conll', header=None, delimiter=r"\s+", engine='python')
wiki.head()
# Out:
#       0       1
# 0  1960  B-DATE
# 1    年代  I-DATE
# 2     と       O
# 3  1970  B-DATE
# 4    年代  I-DATE

# %%
wiki.shape
# Out:
# (142400, 2)

# %%
labels = wiki[1].unique()
labels
# Out:
# array(['B-DATE', 'I-DATE', 'O', 'B-PERSON', 'I-PERSON', None,
#        'B-ARTIFACT', 'B-LOCATION', 'B-NUMBER', 'I-NUMBER', 'B-PERCENT',
#        'I-PERCENT', 'B-TIME', 'I-TIME', 'I-ARTIFACT', 'B-EVENT',
#        'I-EVENT', 'B-ORGANIZATION', 'I-ORGANIZATION', 'I-LOCATION',
#        'B-OTHER', 'I-OTHER', 'B-MONEY', 'I-MONEY'], dtype=object)

# %%
len(labels)
# Out:
# 24

# %%
wiki[1].value_counts()
# Out:
# O                 121564
# B-LOCATION          2853
# I-DATE              2346
# I-ORGANIZATION      1704
# B-ORGANIZATION      1576
# B-DATE              1489
# I-NUMBER            1374
# B-PERSON            1370
# I-ARTIFACT          1236
# I-LOCATION          1136
# B-NUMBER            1027
# I-PERSON             978
# B-ARTIFACT           725
# I-EVENT              591
# I-OTHER              428
# B-OTHER              380
# B-EVENT              260
# I-PERCENT            259
# B-PERCENT            157
# I-MONEY              154
# B-MONEY               67
# I-TIME                38
# B-TIME                17
# Name: 1, dtype: int64

# %%
# Read data
# Annotated Corpus for Named Entity Recognition
# https://www.kaggle.com/abhinavwalia95/entity-annotated-corpus
ner = pd.read_csv("data/entity-annotated-corpus/ner.csv", encoding = "ISO-8859-1", error_bad_lines=False)
ner.head()
# Out:
# b'Skipping line 281837: expected 25 fields, saw 34\n'
#    Unnamed: 0     lemma next-lemma next-next-lemma next-next-pos  \
# 0           0  thousand         of        demonstr           NNS
# 1           1        of   demonstr            have           VBP
# 2           2  demonstr       have           march           VBN
# 3           3      have      march         through            IN
# 4           4     march    through          london           NNP
#
#   next-next-shape next-next-word next-pos next-shape      next-word ...  \
# 0       lowercase  demonstrators       IN  lowercase             of ...
# 1       lowercase           have      NNS  lowercase  demonstrators ...
# 2       lowercase        marched      VBP  lowercase           have ...
# 3       lowercase        through      VBN  lowercase        marched ...
# 4     capitalized         London       IN  lowercase        through ...
#
#   prev-prev-lemma prev-prev-pos prev-prev-shape prev-prev-word   prev-shape  \
# 0      __start2__    __START2__        wildcard     __START2__     wildcard
# 1      __start1__    __START1__        wildcard     __START1__  capitalized
# 2        thousand           NNS     capitalized      Thousands    lowercase
# 3              of            IN       lowercase             of    lowercase
# 4        demonstr           NNS       lowercase  demonstrators    lowercase
#
#        prev-word sentence_idx        shape           word tag
# 0     __START1__          1.0  capitalized      Thousands   O
# 1      Thousands          1.0    lowercase             of   O
# 2             of          1.0    lowercase  demonstrators   O
# 3  demonstrators          1.0    lowercase           have   O
# 4           have          1.0    lowercase        marched   O
#
# [5 rows x 25 columns]

# %%
ner.head(20)
# Out:
#     Unnamed: 0     lemma next-lemma next-next-lemma next-next-pos  \
# 0            0  thousand         of        demonstr           NNS
# 1            1        of   demonstr            have           VBP
# 2            2  demonstr       have           march           VBN
# 3            3      have      march         through            IN
# 4            4     march    through          london           NNP
# 5            5   through     london              to            TO
# 6            6    london         to         protest            VB
# 7            7        to    protest             the            DT
# 8            8   protest        the             war            NN
# 9            9       the        war              in            IN
# 10          10       war         in            iraq           NNP
# 11          11        in       iraq             and            CC
# 12          12      iraq        and          demand            VB
# 13          13       and     demand             the            DT
# 14          14    demand        the        withdraw            NN
# 15          15       the   withdraw              of            IN
# 16          16  withdraw         of         british            JJ
# 17          17        of    british           troop           NNS
# 18          18   british      troop            from            IN
# 19          19     troop       from            that            DT
#
#    next-next-shape next-next-word next-pos   next-shape      next-word  ...    \
# 0        lowercase  demonstrators       IN    lowercase             of  ...
# 1        lowercase           have      NNS    lowercase  demonstrators  ...
# 2        lowercase        marched      VBP    lowercase           have  ...
# 3        lowercase        through      VBN    lowercase        marched  ...
# 4      capitalized         London       IN    lowercase        through  ...
# 5        lowercase             to      NNP  capitalized         London  ...
# 6        lowercase        protest       TO    lowercase             to  ...
# 7        lowercase            the       VB    lowercase        protest  ...
# 8        lowercase            war       DT    lowercase            the  ...
# 9        lowercase             in       NN    lowercase            war  ...
# 10     capitalized           Iraq       IN    lowercase             in  ...
# 11       lowercase            and      NNP  capitalized           Iraq  ...
# 12       lowercase         demand       CC    lowercase            and  ...
# 13       lowercase            the       VB    lowercase         demand  ...
# 14       lowercase     withdrawal       DT    lowercase            the  ...
# 15       lowercase             of       NN    lowercase     withdrawal  ...
# 16     capitalized        British       IN    lowercase             of  ...
# 17       lowercase         troops       JJ  capitalized        British  ...
# 18       lowercase           from      NNS    lowercase         troops  ...
# 19       lowercase           that       IN    lowercase           from  ...
#
#    prev-prev-lemma prev-prev-pos prev-prev-shape prev-prev-word   prev-shape  \
# 0       __start2__    __START2__        wildcard     __START2__     wildcard
# 1       __start1__    __START1__        wildcard     __START1__  capitalized
# 2         thousand           NNS     capitalized      Thousands    lowercase
# 3               of            IN       lowercase             of    lowercase
# 4         demonstr           NNS       lowercase  demonstrators    lowercase
# 5             have           VBP       lowercase           have    lowercase
# 6            march           VBN       lowercase        marched    lowercase
# 7          through            IN       lowercase        through  capitalized
# 8           london           NNP     capitalized         London    lowercase
# 9               to            TO       lowercase             to    lowercase
# 10         protest            VB       lowercase        protest    lowercase
# 11             the            DT       lowercase            the    lowercase
# 12             war            NN       lowercase            war    lowercase
# 13              in            IN       lowercase             in  capitalized
# 14            iraq           NNP     capitalized           Iraq    lowercase
# 15             and            CC       lowercase            and    lowercase
# 16          demand            VB       lowercase         demand    lowercase
# 17             the            DT       lowercase            the    lowercase
# 18        withdraw            NN       lowercase     withdrawal    lowercase
# 19              of            IN       lowercase             of  capitalized
#
#         prev-word sentence_idx        shape           word    tag
# 0      __START1__          1.0  capitalized      Thousands      O
# 1       Thousands          1.0    lowercase             of      O
# 2              of          1.0    lowercase  demonstrators      O
# 3   demonstrators          1.0    lowercase           have      O
# 4            have          1.0    lowercase        marched      O
# 5         marched          1.0    lowercase        through      O
# 6         through          1.0  capitalized         London  B-geo
# 7          London          1.0    lowercase             to      O
# 8              to          1.0    lowercase        protest      O
# 9         protest          1.0    lowercase            the      O
# 10            the          1.0    lowercase            war      O
# 11            war          1.0    lowercase             in      O
# 12             in          1.0  capitalized           Iraq  B-geo
# 13           Iraq          1.0    lowercase            and      O
# 14            and          1.0    lowercase         demand      O
# 15         demand          1.0    lowercase            the      O
# 16            the          1.0    lowercase     withdrawal      O
# 17     withdrawal          1.0    lowercase             of      O
# 18             of          1.0  capitalized        British  B-gpe
# 19        British          1.0    lowercase         troops      O
#
# [20 rows x 25 columns]

# %%
ner = ner[['lemma', 'tag']]
ner.head(50)
# Out:
#         lemma    tag
# 0    thousand      O
# 1          of      O
# 2    demonstr      O
# 3        have      O
# 4       march      O
# 5     through      O
# 6      london  B-geo
# 7          to      O
# 8     protest      O
# 9         the      O
# 10        war      O
# 11         in      O
# 12       iraq  B-geo
# 13        and      O
# 14     demand      O
# 15        the      O
# 16   withdraw      O
# 17         of      O
# 18    british  B-gpe
# 19      troop      O
# 20       from      O
# 21       that      O
# 22    countri      O
# 23          .      O
# 24     famili      O
# 25         of      O
# 26    soldier      O
# 27       kill      O
# 28         in      O
# 29        the      O
# 30   conflict      O
# 31       join      O
# 32        the      O
# 33    protest      O
# 34        who      O
# 35      carri      O
# 36     banner      O
# 37       with      O
# 38       such      O
# 39     slogan      O
# 40         as      O
# 41          "      O
# 42       bush  B-per
# 43     number      O
# 44        one      O
# 45  terrorist      O
# 46          "      O
# 47        and      O
# 48          "      O
# 49       stop      O

# %%
ner.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1050795 entries, 0 to 1050794
# Data columns (total 2 columns):
# lemma    1050795 non-null object
# tag      1050794 non-null object
# dtypes: object(2)
# memory usage: 16.0+ MB

# %%
ner.tag.value_counts()
# Out:
# O        889973
# B-geo     37525
# B-tim     20193
# B-org     20184
# I-per     17382
# B-per     17011
# I-org     16537
# B-gpe     16392
# I-geo      7409
# I-tim      6298
# B-art       434
# B-eve       348
# I-eve       297
# I-art       280
# I-gpe       229
# B-nat       226
# I-nat        76
# Name: tag, dtype: int64

# %%
len(ner.tag.value_counts())
# Out:
# 17

# %%
ner.isna().sum()
# Out:
# lemma    0
# tag      1
# dtype: int64

# %%
ner[ner.tag.isna()]
# Out:
#         lemma  tag
# 689433  domin  NaN

# %%
ner['tag'] = ner['tag'].fillna('O')
ner.iloc[689433]
# Out:
# lemma    domin
# tag          O
# Name: 689433, dtype: object

# %%
ner.isna().sum()
# Out:
# lemma    0
# tag      0
# dtype: int64

# %%
ner.iloc[689423:689443]
# Out:
#              lemma    tag
# 689423      altern      O
# 689424      energi      O
# 689425       sourc      O
# 689426          to      O
# 689427       avoid      O
# 689428          be      O
# 689429          at      O
# 689430         the      O
# 689431       merci      O
# 689432          of      O
# 689433       domin      O
# 689434      pascal  B-per
# 689435  yoadimadji  I-per
# 689436         has      O
# 689437         die      O
# 689438          in      O
# 689439        pari  B-geo
# 689440          at      O
# 689441         the      O
# 689442         age      O

# %%
ner.shape
# Out:
# (1050795, 2)

# %%
ner[ner['tag'] == 'B-per']['lemma'].unique()[:20]
# Out:
# array(['bush', 'presid', 'thoma', 'prophet', 'omar', 'khayam', 'malik',
#        'abdul', 'khan', 'nancy-amelia', 'tim', 'harcourt', 'foreign',
#        'mr.', 'cholili', 'azahari', 'pope', 'sister', 'byzantin', 'ahm'],
#       dtype=object)

# %%
ner[ner['tag'] == 'B-org']['lemma'].unique()[:20]
# Out:
# array(['labor', 'intern', 'iaea', 'european', 'u.n.', 'bilfing',
#        'royal-dutch', 'shell', 'al', 'sunni', 'muslim', 'brotherhood',
#        'mutahida', 'taleban', 'islam', 'british', 'home', 'associ', 'ap',
#        'al-qaida'], dtype=object)

# %%
ner[ner['tag'] == 'B-geo']['lemma'].unique()[:20]
# Out:
# array(['london', 'iraq', 'hyde', 'britain', 'brighton', 'rome', 'pari',
#        'madrid', 'vienna', 'isfahan', 'nigeria', 'delta', 'bayelsa',
#        'niger', 'somalia', 'mogadishu', 'mosul', 'sunni', 'kurdish',
#        'anbar'], dtype=object)

# %%
ner[ner['tag'] == 'B-gpe']['lemma'].unique()[:20]
# Out:
# array(['british', 'english', 'britain', 'iran', 'iranian', 'u.s.',
#        'tehran', 'european', 'german', 'nigerian', 'nigeria', 'somali',
#        'iraqi', 'american', 'egyptian', 'bedfordshir', 'pakistani',
#        'pakistan', 'unit', 'libya'], dtype=object)

# %%
ner[ner['tag'] == 'B-tim']['lemma'].unique()[:100]
# Out:
# array(['wednesday', 'tuesday', 'sunday', 'saturday', 'friday', 'thursday',
#        '2001', '2004', 'septemb', '9', '1995', 'april', 'octob', '2002',
#        '2003', 'decemb', 'novemb', 'august', '2000', 'june', '3', '2009',
#        '2008', 'monday', 'juli', '1970s', '1980s', 'januari', 'march',
#        'midnight', '1990', '2012', '2005', 'neolith', 'new', 'may',
#        '1976', 'a.d.', '1940', '1991', '1994', '1990s', '2010', '1968',
#        '2006', '2007', '19th', '1834', '1845', '1917', '1910', '1962',
#        '2017', '1954', 'tombston', '27', 'each', '120', 'from',
#        'three-day', 'first', 'two', 'end', 'of', 'recent', 'midday',
#        'fourth', '1657', '70th', 'few', 'one', '1992', 'almost',
#        'between', "'s", 'later', '13', 'in', 'kamdesh', 'more', 'u.s.-l',
#        '80th', 'second', 'februari', '1974', 'today', 'releas', '1998',
#        '13th', 'six', '1961', '2030', 'three', '11th', 'cosmonaut',
#        '1960s', 'sinc', 'past', '20', 'four-year'], dtype=object)

# %%
ner.to_csv('data/entity-annotated-corpus/ner_labeled_data.tsv', sep='\t', header=False, index=False)

# %%
# Cleaned data
ner_cleaned = pd.read_csv("data/entity-annotated-corpus/ner_dataset.csv", encoding = "ISO-8859-1", error_bad_lines=False)
ner_cleaned.head()
# Out:
#     Sentence #           Word  POS Tag
# 0  Sentence: 1      Thousands  NNS   O
# 1          NaN             of   IN   O
# 2          NaN  demonstrators  NNS   O
# 3          NaN           have  VBP   O
# 4          NaN        marched  VBN   O

# %%
ner_cleaned.head(55)
# Out:
#      Sentence #           Word  POS    Tag
# 0   Sentence: 1      Thousands  NNS      O
# 1           NaN             of   IN      O
# 2           NaN  demonstrators  NNS      O
# 3           NaN           have  VBP      O
# 4           NaN        marched  VBN      O
# 5           NaN        through   IN      O
# 6           NaN         London  NNP  B-geo
# 7           NaN             to   TO      O
# 8           NaN        protest   VB      O
# 9           NaN            the   DT      O
# 10          NaN            war   NN      O
# 11          NaN             in   IN      O
# 12          NaN           Iraq  NNP  B-geo
# 13          NaN            and   CC      O
# 14          NaN         demand   VB      O
# 15          NaN            the   DT      O
# 16          NaN     withdrawal   NN      O
# 17          NaN             of   IN      O
# 18          NaN        British   JJ  B-gpe
# 19          NaN         troops  NNS      O
# 20          NaN           from   IN      O
# 21          NaN           that   DT      O
# 22          NaN        country   NN      O
# 23          NaN              .    .      O
# 24  Sentence: 2       Families  NNS      O
# 25          NaN             of   IN      O
# 26          NaN       soldiers  NNS      O
# 27          NaN         killed  VBN      O
# 28          NaN             in   IN      O
# 29          NaN            the   DT      O
# 30          NaN       conflict   NN      O
# 31          NaN         joined  VBD      O
# 32          NaN            the   DT      O
# 33          NaN     protesters  NNS      O
# 34          NaN            who   WP      O
# 35          NaN        carried  VBD      O
# 36          NaN        banners  NNS      O
# 37          NaN           with   IN      O
# 38          NaN           such   JJ      O
# 39          NaN        slogans  NNS      O
# 40          NaN             as   IN      O
# 41          NaN              "   ``      O
# 42          NaN           Bush  NNP  B-per
# 43          NaN         Number   NN      O
# 44          NaN            One   CD      O
# 45          NaN      Terrorist   NN      O
# 46          NaN              "   ``      O
# 47          NaN            and   CC      O
# 48          NaN              "   ``      O
# 49          NaN           Stop   VB      O
# 50          NaN            the   DT      O
# 51          NaN       Bombings  NNS      O
# 52          NaN              .    .      O
# 53          NaN              "   ``      O
# 54  Sentence: 3           They  PRP      O

# %%
ner_cleaned.shape
# Out:
# (1048575, 4)

# %%
ner_cleaned.Tag.value_counts()
# Out:
# O        887908
# B-geo     37644
# B-tim     20333
# B-org     20143
# I-per     17251
# B-per     16990
# I-org     16784
# B-gpe     15870
# I-geo      7414
# I-tim      6528
# B-art       402
# B-eve       308
# I-art       297
# I-eve       253
# B-nat       201
# I-gpe       198
# I-nat        51
# Name: Tag, dtype: int64

# %%
len(ner_cleaned.Tag.value_counts())
# Out:
# 17

# %%
ner_cleaned.isna().sum()
# Out:
# Sentence #    1000616
# Word                0
# POS                 0
# Tag                 0
# dtype: int64

# %%
ner_cleaned[ner_cleaned['Tag'] == 'B-per']['Word'].unique()[:20]
# Out:
# array(['Bush', 'President', 'Thomas', 'Prophet', 'Omar', 'Khayam',
#        'Malik', 'Abdul', 'Khan', 'Nancy-Amelia', 'Tim', 'Harcourt',
#        'Foreign', 'Mr.', 'Cholily', 'Azahari', 'Pope', 'Sister',
#        'Byzantine', 'Ahmed'], dtype=object)

# %%
ner_cleaned[ner_cleaned['Tag'] == 'B-org']['Word'].unique()[:20]
# Out:
# array(['Labor', 'International', 'IAEA', 'European', 'U.N.', 'Bilfinger',
#        'Royal-Dutch', 'Shell', 'al', 'Sunni', 'Muslim', 'Brotherhood',
#        'Mutahida', 'Taleban', 'Islam', 'British', 'Home', 'Associated',
#        'AP', 'al-Qaida'], dtype=object)

# %%
ner_cleaned[ner_cleaned['Tag'] == 'B-geo']['Word'].unique()[:20]
# Out:
# array(['London', 'Iraq', 'Hyde', 'Britain', 'Brighton', 'Rome', 'Paris',
#        'Madrid', 'Vienna', 'Isfahan', 'Nigeria', 'Delta', 'Bayelsa',
#        'Niger', 'Somalia', 'Mogadishu', 'Mosul', 'Sunni', 'Kurdish',
#        'Anbar'], dtype=object)

# %%
ner_cleaned[ner_cleaned['Tag'] == 'B-gpe']['Word'].unique()[:20]
# Out:
# array(['British', 'English', 'Britain', 'Iran', 'Iranian', 'U.S.',
#        'Tehran', 'European', 'Germans', 'Nigerian', 'German', 'Nigeria',
#        'Somali', 'Iraqi', 'American', 'Egyptian', 'Bedfordshire',
#        'Pakistani', 'Pakistan', 'United'], dtype=object)

# %%
ner_cleaned[ner_cleaned['Tag'] == 'B-tim']['Word'].unique()[:20]
# Out:
# array(['Wednesday', 'Tuesday', 'Sunday', 'Saturday', 'Friday', 'Thursday',
#        '2001', '2004', 'September', '9', '1995', 'April', 'October',
#        '2002', '2003', 'December', 'November', 'August', '2000', 'June'],
#       dtype=object)

# %%
ner_cleaned[ner_cleaned['Tag'] == 'B-art']['Word'].unique()[:20]
# Out:
# array(['Nuclear', 'Saltillo', 'Pentastar', 'Chrysler', 'Dodge', 'Jeep',
#        'Ram', 'Vioxx', 'The', 'Good', '20/20', 'Web', 'english', 'Daily',
#        'alHurra', 'Charles', 'Baghdad', 'Association', 'Huygens',
#        'Cassini'], dtype=object)

# %%
ner_cleaned[ner_cleaned['Tag'] == 'B-eve']['Word'].unique()[:20]
# Out:
# array(['2012', 'Games', '2008', 'Operation', 'Gulf', 'Australian',
#        'Kooyong', 'World', 'Ashura', 'Christmas', 'Olympic', 'Delray',
#        'II', 'Hurricane', 'Korean', 'Beijing', 'I', 'New', 'Eve', 'Grand'],
#       dtype=object)

# %%
ner_cleaned[ner_cleaned['Tag'] == 'B-nat']['Word'].unique()[:20]
# Out:
# array(['H5N1', 'Jing', 'SARS', 'Severe', 'HIV', 'AIDS', 'Hurricane',
#        'Katrina', 'Ills', 'H5N2', 'XDR-TB', 'Marburg', 'Tropical', 'H1N1',
#        'Bird', 'heart', 'Type', 'Rita', 'Hurricanes', 'Amur'],
#       dtype=object)

# %%
ner_cleaned.dropna().head()
# Out:
#      Sentence #       Word  POS Tag
# 0   Sentence: 1  Thousands  NNS   O
# 24  Sentence: 2   Families  NNS   O
# 54  Sentence: 3       They  PRP   O
# 68  Sentence: 4     Police  NNS   O
# 83  Sentence: 5        The   DT   O

# %%
indices = ner_cleaned.dropna().index
indices[:20]
# Out:
# Int64Index([  0,  24,  54,  68,  83, 108, 132, 153, 181, 196, 221, 233, 267,
#             296, 322, 362, 372, 394, 428, 448],
#            dtype='int64')

# %%
delimiters = ner_cleaned.iloc[indices - 1]
delimiters.head()
# Out:
#         Sentence #    Word POS Tag
# 1048574        NaN  attack  NN   O
# 23             NaN       .   .   O
# 53             NaN       "  ``   O
# 67             NaN       .   .   O
# 82             NaN       .   .   O

# %%
delimiters['Word'].value_counts()
# Out:
# .                 47068
# "                   684
# :                    30
# U.S.                 21
# '                    13
# ?                     8
# ...                   8
# !                     7
# D.C.                  5
# Baghdad               4
# )                     3
# ,                     3
# country               3
# that                  2
# enter                 2
# Garang                2
# -                     2
# reporters             2
# Bush                  2
#                      2
# years                 2
# Monday                2
# ..                    1
# involvement           1
# LRA..                 1
# Akayeva               1
# Iraq                  1
# Base                  1
# 2010                  1
# Party                 1
#                   ...
# M.C.                  1
# both                  1
# door                  1
# Grill                 1
# 20th                  1
# prayer                1
# million               1
# Florida               1
# Gnassingbe            1
# Swaziland             1
# The                   1
# Erdogan               1
# killed                1
# selfish               1
# Mass.                 1
# opponent              1
# Co.                   1
# Paz                   1
# months                1
# 2003                  1
# B.C.                  1
# Camp                  1
# activities            1
# Roche                 1
# province              1
# Jr.                   1
# away                  1
# demonstrations        1
# nothing               1
# Islamabad             1
# Name: Word, Length: 106, dtype: int64

# %%
ner_out = ner_cleaned[['Sentence #', 'Word', 'Tag']]
ner_out.head()
# Out:
#     Sentence #           Word Tag
# 0  Sentence: 1      Thousands   O
# 1          NaN             of   O
# 2          NaN  demonstrators   O
# 3          NaN           have   O
# 4          NaN        marched   O

# %%
ner_out['Sentence #'] = ner_out['Sentence #'].fillna('c')
ner_out.head()
# Out:
# /Users/kei/anaconda/lib/python3.5/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#     Sentence #           Word Tag
# 0  Sentence: 1      Thousands   O
# 1            c             of   O
# 2            c  demonstrators   O
# 3            c           have   O
# 4            c        marched   O

# %%
def my_map(x):
    if x != 'c':
        _, n = x.split()
        return n
    else:
        return 'c'

ner_out['Sentence #'] = ner_out['Sentence #'].map(my_map)
ner_out.head(55)
# Out:
# /Users/kei/anaconda/lib/python3.5/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#    Sentence #           Word    Tag
# 0           1      Thousands      O
# 1           c             of      O
# 2           c  demonstrators      O
# 3           c           have      O
# 4           c        marched      O
# 5           c        through      O
# 6           c         London  B-geo
# 7           c             to      O
# 8           c        protest      O
# 9           c            the      O
# 10          c            war      O
# 11          c             in      O
# 12          c           Iraq  B-geo
# 13          c            and      O
# 14          c         demand      O
# 15          c            the      O
# 16          c     withdrawal      O
# 17          c             of      O
# 18          c        British  B-gpe
# 19          c         troops      O
# 20          c           from      O
# 21          c           that      O
# 22          c        country      O
# 23          c              .      O
# 24          2       Families      O
# 25          c             of      O
# 26          c       soldiers      O
# 27          c         killed      O
# 28          c             in      O
# 29          c            the      O
# 30          c       conflict      O
# 31          c         joined      O
# 32          c            the      O
# 33          c     protesters      O
# 34          c            who      O
# 35          c        carried      O
# 36          c        banners      O
# 37          c           with      O
# 38          c           such      O
# 39          c        slogans      O
# 40          c             as      O
# 41          c              "      O
# 42          c           Bush  B-per
# 43          c         Number      O
# 44          c            One      O
# 45          c      Terrorist      O
# 46          c              "      O
# 47          c            and      O
# 48          c              "      O
# 49          c           Stop      O
# 50          c            the      O
# 51          c       Bombings      O
# 52          c              .      O
# 53          c              "      O
# 54          3           They      O

# %%
output_file = 'data/test_empty_line_inserted.tsv'

with open(output_file, mode='w') as f:
    for i, row in ner_out.iterrows():
        row_list = row.tolist()
        if i != 0 and row_list[0] != 'c':
             f.write('\n')
        f.write(row_list[1] + '\t' + row_list[2] + '\n')

# %%
# ner_out.to_csv('data/entity-annotated-corpus/ner_labeled_data.tsv', sep='\t', header=False, index=False)
